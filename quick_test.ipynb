# %%
import math
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras 
from tensorflow.python.keras.layers import Input, Dense,LSTM,GRU
from tensorflow.python.keras.models import Sequential
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_excel('oil_date.xlsx')
df.head()
# Out:
#         date   oil
# 0 2021-06-24  0.19
# 1 2021-06-25  0.57
# 2 2021-06-26  1.03
# 3 2021-06-27  1.38
# 4 2021-06-28  1.42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    633 non-null    datetime64[ns]
#  1   oil     633 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 10.0 KB

# %%
plt.figure(figsize=(16,8))
plt.title('Oil Production History')
plt.plot(df['oil'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Oil Rate (m³)',fontsize=18)
plt.show()

# %%
#Create a new dataframe with only the 'Close' column
data = df.filter(['oil'])
#Converting the dataframe to a numpy array
dataset = data.values
#Get /Compute the number of rows to train the model on
training_data_len = math.ceil( len(dataset) *.8)

# %%
#Scale the all of the data to be values between 0 and 1 
scaler = MinMaxScaler(feature_range=(0, 1)) 
scaled_data = scaler.fit_transform(dataset)

# %%
#Create the scaled training data set 
train_data = scaled_data[0:training_data_len  , : ]
#Split the data into x_train and y_train data sets
x_train = []
y_train = []
for i in range(100,len(train_data)):
    x_train.append(train_data[i-100:i,0])
    y_train.append(train_data[i,0])

# %%
#Convert x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
#Reshape the data into the shape accepted by the LSTM
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
#Build the LSTM network model
#to have two LSTM layers with 50 neurons and two Dense layers, one with 25 neurons and the other with 1 neuron.
model = Sequential()
model.add(LSTM(units=64, return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=64, return_sequences=False))
model.add(Dense(units=32))
model.add(Dense(units=1))
optimizer = keras.optimizers.Adam(learning_rate = 0.0007007754058308959,decay=0.9242461402242185)

# %%
#Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#Train the model
history=model.fit(x_train, y_train, batch_size=15, epochs=50,validation_split=0.25)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 15s 364ms/step - loss: 0.0563 - val_loss: 0.0043
# Epoch 2/50
# 21/21 [==============================] - 6s 275ms/step - loss: 0.0081 - val_loss: 0.0018
# Epoch 3/50
# 21/21 [==============================] - 5s 216ms/step - loss: 0.0055 - val_loss: 0.0015
# Epoch 4/50
# 21/21 [==============================] - 4s 214ms/step - loss: 0.0047 - val_loss: 0.0013
# Epoch 5/50
# 21/21 [==============================] - 5s 215ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 6/50
# 21/21 [==============================] - 4s 213ms/step - loss: 0.0048 - val_loss: 0.0013
# Epoch 7/50
# 21/21 [==============================] - 5s 217ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 8/50
# 21/21 [==============================] - 5s 217ms/step - loss: 0.0041 - val_loss: 0.0015
# Epoch 9/50
# 21/21 [==============================] - 5s 223ms/step - loss: 0.0048 - val_loss: 0.0016
# Epoch 10/50
# 21/21 [==============================] - 4s 210ms/step - loss: 0.0041 - val_loss: 0.0020
# Epoch 11/50
# 21/21 [==============================] - 4s 211ms/step - loss: 0.0050 - val_loss: 0.0012
# Epoch 12/50
# 21/21 [==============================] - 4s 212ms/step - loss: 0.0039 - val_loss: 0.0013
# Epoch 13/50
# 21/21 [==============================] - 4s 216ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 14/50
# 21/21 [==============================] - 5s 227ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 15/50
# 21/21 [==============================] - 4s 211ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 16/50
# 21/21 [==============================] - 4s 212ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 17/50
# 21/21 [==============================] - 5s 216ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 18/50
# 21/21 [==============================] - 4s 214ms/step - loss: 0.0034 - val_loss: 0.0010
# Epoch 19/50
# 21/21 [==============================] - 5s 220ms/step - loss: 0.0034 - val_loss: 0.0010
# Epoch 20/50
# 21/21 [==============================] - 4s 210ms/step - loss: 0.0033 - val_loss: 0.0017
# Epoch 21/50
# 21/21 [==============================] - 4s 214ms/step - loss: 0.0029 - val_loss: 0.0012
# Epoch 22/50
# 21/21 [==============================] - 4s 210ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 23/50
# 21/21 [==============================] - 5s 243ms/step - loss: 0.0030 - val_loss: 0.0016
# Epoch 24/50
# 21/21 [==============================] - 6s 264ms/step - loss: 0.0030 - val_loss: 0.0011
# Epoch 25/50
# 21/21 [==============================] - 5s 228ms/step - loss: 0.0029 - val_loss: 8.9508e-04
# Epoch 26/50
# 21/21 [==============================] - 5s 230ms/step - loss: 0.0030 - val_loss: 0.0012
# Epoch 27/50
# 21/21 [==============================] - 5s 226ms/step - loss: 0.0033 - val_loss: 9.3415e-04
# Epoch 28/50
# 21/21 [==============================] - 5s 239ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 29/50
# 21/21 [==============================] - 5s 221ms/step - loss: 0.0030 - val_loss: 9.9049e-04
# Epoch 30/50
# 21/21 [==============================] - 4s 211ms/step - loss: 0.0027 - val_loss: 8.0167e-04
# Epoch 31/50
# 21/21 [==============================] - 4s 212ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 32/50
# 21/21 [==============================] - 5s 219ms/step - loss: 0.0024 - val_loss: 0.0012
# Epoch 33/50
# 21/21 [==============================] - 5s 224ms/step - loss: 0.0032 - val_loss: 9.9676e-04
# Epoch 34/50
# 21/21 [==============================] - 5s 219ms/step - loss: 0.0026 - val_loss: 7.7130e-04
# Epoch 35/50
# 21/21 [==============================] - 4s 211ms/step - loss: 0.0029 - val_loss: 0.0022
# Epoch 36/50
# 21/21 [==============================] - 4s 213ms/step - loss: 0.0030 - val_loss: 0.0017
# Epoch 37/50
# 21/21 [==============================] - 5s 214ms/step - loss: 0.0022 - val_loss: 9.8002e-04
# Epoch 38/50
# 21/21 [==============================] - 4s 213ms/step - loss: 0.0022 - val_loss: 7.1882e-04
# Epoch 39/50
# 21/21 [==============================] - 5s 219ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 40/50
# 21/21 [==============================] - 4s 206ms/step - loss: 0.0021 - val_loss: 8.2866e-04
# Epoch 41/50
# 21/21 [==============================] - 4s 213ms/step - loss: 0.0023 - val_loss: 8.1582e-04
# Epoch 42/50
# 21/21 [==============================] - 4s 211ms/step - loss: 0.0020 - val_loss: 6.5801e-04
# Epoch 43/50
# 21/21 [==============================] - 5s 218ms/step - loss: 0.0019 - val_loss: 6.7567e-04
# Epoch 44/50
# 21/21 [==============================] - 4s 212ms/step - loss: 0.0020 - val_loss: 6.3394e-04
# Epoch 45/50
# 21/21 [==============================] - 4s 213ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 46/50
# 21/21 [==============================] - 4s 214ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 47/50
# 21/21 [==============================] - 4s 214ms/step - loss: 0.0019 - val_loss: 6.9823e-04
# Epoch 48/50
# 21/21 [==============================] - 4s 211ms/step - loss: 0.0019 - val_loss: 7.7601e-04
# Epoch 49/50
# 21/21 [==============================] - 5s 231ms/step - loss: 0.0021 - val_loss: 9.5367e-04
# Epoch 50/50
# 21/21 [==============================] - 5s 216ms/step - loss: 0.0021 - val_loss: 5.9162e-04

# %%
def plot_metric(history,metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()
    return train_metrics, val_metrics

# %%
a,b=plot_metric(history, 'loss')

# %%
#Test data set
test_data = scaled_data[training_data_len - 100: , : ]
#Create the x_test and y_test data sets
x_test = []
y_test =  dataset[training_data_len : , : ] 
for i in range(100,len(test_data)):
    x_test.append(test_data[i-100:i,0])

# %%
#Convert x_test to a numpy array 
x_test = np.array(x_test)
#Reshape the data into the shape accepted by the LSTM
x_test = np.reshape(x_test, (x_test.shape[0],x_test.shape[1],1))

# %%
#Getting the models predicted price values
predictions = model.predict(x_test) 
predictions = scaler.inverse_transform(predictions)#Undo scaling

# %%
#Calculate/Get the value of RMSE(数值越低越好)
#np.dot(np.ones([116, 1]), np.ones([126, 1])).shape
rmse=np.sqrt(np.mean(((predictions - y_test)**2)))
rmse
# Out:
# 0.026412764526643203

# %%
mse = np.mean(((predictions - y_test)**2))
mse
# Out:
# 0.0006976341299399015

# %%
#Plot/Create the data for the graph
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
#Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Oil Rate (m³)', fontsize=18)
plt.plot(train['oil'])
plt.plot(valid[['oil', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')

plt.show()
output3 = pd.DataFrame(train)
output3.to_csv('train.csv', index = None, encoding = "utf-8_sig", header = None)
output4 = pd.DataFrame(valid)
output4.to_csv('valid.csv', index = None, encoding = "utf-8_sig", header = None)
# Out:
# C:\Users\15966\AppData\Local\Temp\ipykernel_14856\473666728.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# %%
valid
# Out:
#       oil  Predictions
# 507  1.07     1.076093
# 508  1.08     1.076104
# 509  1.09     1.080009
# 510  1.09     1.087178
# 511  1.09     1.092258
# ..    ...          ...
# 628  0.96     0.970321
# 629  0.94     0.972533
# 630  0.96     0.966019
# 631  0.94     0.967000
# 632  1.00     0.961932
#
# [126 rows x 2 columns]

# %%
model.save('lstm_model.h5')

# %%
predictions_training = model.predict(x_train) 
predictions_training = scaler.inverse_transform(predictions_training)#Undo scaling

# %%
predictions_training
# Out:
# array([[0.6064048 ],
#        [0.65447044],
#        [0.6819419 ],
#        [0.70052356],
#        [0.72605157],
#        [0.7352229 ],
#        [0.74002844],
#        [0.7387773 ],
#        [0.7333117 ],
#        [0.71599406],
#        [0.7114969 ],
#        [0.7253835 ],
#        [0.7338387 ],
#        [0.72559905],
#        [0.71261394],
#        [0.7091132 ],
#        [0.7126613 ],
#        [0.70755124],
#        [0.71155816],
#        [0.71992713],
#        [0.72357404],
#        [0.7150441 ],
#        [0.69633687],
#        [0.6777594 ],
#        [0.668395  ],
#        [0.6772803 ],
#        [0.67904913],
#        [0.6690427 ],
#        [0.6652054 ],
#        [0.66412055],
#        [0.6516334 ],
#        [0.64617634],
#        [0.64426017],
#        [0.64704716],
#        [0.64404345],
#        [0.63725394],
#        [0.6252884 ],
#        [0.6278278 ],
#        [0.6304856 ],
#        [0.6324071 ],
#        [0.64581925],
#        [0.6488587 ],
#        [0.6479739 ],
#        [0.6337168 ],
#        [0.63863075],
#        [0.6441757 ],
#        [0.64520305],
#        [0.6446633 ],
#        [0.6438167 ],
#        [0.64004076],
#        [0.6366522 ],
#        [0.63136613],
#        [0.6211251 ],
#        [0.61277056],
#        [0.60150445],
#        [0.59604025],
#        [0.59393215],
#        [0.59348834],
#        [0.59668434],
#        [0.59988695],
#        [0.5990063 ],
#        [0.60014147],
#        [0.5983307 ],
#        [0.59615386],
#        [0.59445244],
#        [0.6115593 ],
#        [0.6288023 ],
#        [0.6438849 ],
#        [0.65351886],
#        [0.6677696 ],
#        [0.68179625],
#        [0.7103245 ],
#        [0.76965624],
#        [0.82868767],
#        [0.88157725],
#        [0.9068527 ],
#        [0.92544174],
#        [0.94185084],
#        [0.9513365 ],
#        [0.9592153 ],
#        [0.9713665 ],
#        [0.9805572 ],
#        [0.98617005],
#        [0.9893185 ],
#        [0.9911825 ],
#        [0.9851018 ],
#        [0.9836156 ],
#        [0.9842476 ],
#        [0.9856674 ],
#        [0.9871354 ],
#        [0.9920341 ],
#        [0.99978447],
#        [1.0053611 ],
#        [1.0045055 ],
#        [1.0247586 ],
#        [1.0422957 ],
#        [1.0869036 ],
#        [1.1009822 ],
#        [1.0820417 ],
#        [1.0733731 ],
#        [1.0700514 ],
#        [1.0774324 ],
#        [1.0462874 ],
#        [1.0192543 ],
#        [1.0345141 ],
#        [1.1447024 ],
#        [1.2167478 ],
#        [1.2006594 ],
#        [1.1676255 ],
#        [1.1419283 ],
#        [1.1281264 ],
#        [1.123551  ],
#        [1.1241987 ],
#        [1.126908  ],
#        [1.1297904 ],
#        [1.1319971 ],
#        [1.1333342 ],
#        [1.1379323 ],
#        [1.1413083 ],
#        [1.1428788 ],
#        [1.1431657 ],
#        [1.146843  ],
#        [1.1617314 ],
#        [1.1770205 ],
#        [1.2022296 ],
#        [1.2436601 ],
#        [1.2876252 ],
#        [1.2777716 ],
#        [1.220271  ],
#        [1.1805412 ],
#        [1.16227   ],
#        [1.1625546 ],
#        [1.1689034 ],
#        [1.2001625 ],
#        [1.2413914 ],
#        [1.2505313 ],
#        [1.2138158 ],
#        [1.1731173 ],
#        [1.1483879 ],
#        [1.1383727 ],
#        [1.1942754 ],
#        [1.2392591 ],
#        [1.2673606 ],
#        [1.2567966 ],
#        [1.2442867 ],
#        [1.29059   ],
#        [1.3341163 ],
#        [1.3706312 ],
#        [1.3873123 ],
#        [1.389615  ],
#        [1.3720405 ],
#        [1.3573061 ],
#        [1.3276731 ],
#        [1.1672544 ],
#        [1.0270085 ],
#        [0.9597548 ],
#        [0.94707054],
#        [1.0079781 ],
#        [1.1279608 ],
#        [1.1658461 ],
#        [1.1827655 ],
#        [1.2279857 ],
#        [1.2828127 ],
#        [1.2923746 ],
#        [1.2836671 ],
#        [1.2672716 ],
#        [1.2550745 ],
#        [1.2493587 ],
#        [1.2486917 ],
#        [1.25082   ],
#        [1.2581697 ],
#        [1.2643878 ],
#        [1.268201  ],
#        [1.2232131 ],
#        [1.1878643 ],
#        [1.1498293 ],
#        [1.1290282 ],
#        [1.1222689 ],
#        [1.1919248 ],
#        [1.251793  ],
#        [1.2884688 ],
#        [1.3015599 ],
#        [1.3003038 ],
#        [1.2935921 ],
#        [1.2869555 ],
#        [1.2826916 ],
#        [1.2810323 ],
#        [1.281278  ],
#        [1.2825418 ],
#        [1.2841079 ],
#        [1.2725645 ],
#        [1.2637223 ],
#        [1.2597477 ],
#        [1.2591491 ],
#        [1.2600536 ],
#        [1.2697668 ],
#        [1.2772126 ],
#        [1.280711  ],
#        [1.2813268 ],
#        [1.2805296 ],
#        [1.2750789 ],
#        [1.2708304 ],
#        [1.2687087 ],
#        [1.2810965 ],
#        [1.3262618 ],
#        [1.3631172 ],
#        [1.3805834 ],
#        [1.3836652 ],
#        [1.3754672 ],
#        [1.3402119 ],
#        [1.387398  ],
#        [1.4311502 ],
#        [1.412482  ],
#        [1.4624884 ],
#        [1.4641479 ],
#        [1.4349087 ],
#        [1.411992  ],
#        [1.4014413 ],
#        [1.4044454 ],
#        [1.4057128 ],
#        [1.4823095 ],
#        [1.5825496 ],
#        [1.5825636 ],
#        [1.5905145 ],
#        [1.5401082 ],
#        [1.5453194 ],
#        [1.6546932 ],
#        [1.7296617 ],
#        [1.7537273 ],
#        [1.7084987 ],
#        [1.689146  ],
#        [1.6290319 ],
#        [1.4070528 ],
#        [1.2871569 ],
#        [1.2482017 ],
#        [1.2545298 ],
#        [1.2975303 ],
#        [1.2795599 ],
#        [1.2588708 ],
#        [1.245873  ],
#        [1.248009  ],
#        [1.2261999 ],
#        [1.1998025 ],
#        [1.1379341 ],
#        [1.0557408 ],
#        [1.0049042 ],
#        [0.97929674],
#        [1.0016503 ],
#        [1.0281311 ],
#        [1.0463139 ],
#        [1.1012893 ],
#        [1.123174  ],
#        [1.0955918 ],
#        [1.0195609 ],
#        [0.9993405 ],
#        [0.9999989 ],
#        [0.99935615],
#        [1.0034574 ],
#        [1.0075879 ],
#        [1.0103371 ],
#        [1.0266621 ],
#        [1.0398132 ],
#        [1.0544671 ],
#        [1.0824809 ],
#        [1.0905752 ],
#        [1.1017076 ],
#        [1.1082854 ],
#        [1.110665  ],
#        [1.0989733 ],
#        [1.0886672 ],
#        [1.06745   ],
#        [1.0605938 ],
#        [1.0643482 ],
#        [1.058368  ],
#        [1.053078  ],
#        [1.0122161 ],
#        [1.0323204 ],
#        [1.0554742 ],
#        [1.0519581 ],
#        [1.0432304 ],
#        [1.0360286 ],
#        [1.0317055 ],
#        [1.0334927 ],
#        [1.0360895 ],
#        [1.0379193 ],
#        [1.0387928 ],
#        [1.0504155 ],
#        [1.0830901 ],
#        [1.1276274 ],
#        [1.1610367 ],
#        [1.1651369 ],
#        [1.1590695 ],
#        [1.1478312 ],
#        [1.1396505 ],
#        [1.1358248 ],
#        [1.1352698 ],
#        [1.1364757 ],
#        [1.1746398 ],
#        [1.145219  ],
#        [1.117039  ],
#        [1.1003202 ],
#        [1.1054825 ],
#        [1.1184067 ],
#        [1.1008804 ],
#        [1.0719932 ],
#        [1.059756  ],
#        [1.0258069 ],
#        [1.0048007 ],
#        [0.9692777 ],
#        [0.94485337],
#        [0.92546546],
#        [0.9476271 ],
#        [0.96849626],
#        [0.98153025],
#        [1.0055774 ],
#        [1.0112206 ],
#        [1.0129695 ],
#        [1.0345596 ],
#        [1.0597619 ],
#        [1.0757264 ],
#        [1.0671546 ],
#        [1.0746714 ],
#        [1.0865366 ],
#        [1.0949013 ],
#        [1.0991867 ],
#        [1.1007985 ],
#        [1.1011828 ],
#        [1.1012639 ],
#        [1.0779823 ],
#        [1.0784602 ],
#        [1.0806779 ],
#        [1.0637281 ],
#        [1.0495052 ],
#        [1.0881302 ],
#        [1.1246653 ],
#        [1.146468  ],
#        [1.1550459 ],
#        [1.1556811 ],
#        [1.1530846 ],
#        [1.1181723 ],
#        [1.0864105 ],
#        [1.0687361 ],
#        [1.0278374 ],
#        [1.0414414 ],
#        [1.0633607 ],
#        [1.0798635 ],
#        [1.0886409 ],
#        [1.1228302 ],
#        [1.1447504 ],
#        [1.1460397 ],
#        [1.1406077 ],
#        [1.1228088 ],
#        [1.1051247 ],
#        [1.0869819 ],
#        [1.0689828 ],
#        [1.0591484 ],
#        [1.0560112 ],
#        [1.0564792 ],
#        [1.0619793 ],
#        [1.0628446 ],
#        [1.0622265 ],
#        [1.0535475 ],
#        [1.046133  ],
#        [1.0341027 ],
#        [1.025704  ],
#        [0.9952055 ],
#        [0.9716552 ],
#        [0.9589473 ],
#        [0.9250967 ],
#        [0.93551767],
#        [1.0009468 ],
#        [1.0569419 ],
#        [1.0892155 ],
#        [1.0974948 ],
#        [1.094524  ],
#        [1.0961359 ],
#        [1.0973542 ],
#        [1.0978391 ],
#        [1.1020348 ],
#        [1.0939599 ],
#        [1.086732  ],
#        [1.083012  ],
#        [1.0821844 ],
#        [1.082932  ],
#        [1.084183  ],
#        [1.0853176 ],
#        [1.0899911 ],
#        [1.0936364 ],
#        [1.0955222 ],
#        [1.0921631 ],
#        [1.077072  ],
#        [1.0652218 ],
#        [1.0589148 ],
#        [1.0567572 ],
#        [1.064513  ],
#        [1.0718093 ],
#        [1.0762067 ],
#        [1.0779796 ],
#        [1.0781235 ],
#        [1.0736711 ],
#        [1.0735872 ],
#        [1.0744675 ],
#        [1.0752729 ],
#        [1.0757669 ],
#        [1.0759981 ],
#        [1.0760766 ],
#        [1.0760912 ]], dtype=float32)

# %%
data_training= np.concatenate([predictions_training, predictions])

# %%
data_training = data_training.ravel()

# %%
a = np.empty((df.shape[0],1,)).ravel()
a[:] = np.nan
a[100:] = data_training

# %%
df = df.set_index('date')

# %%
df["prediction"] = a

# %%
df
# Out:
#              oil  prediction
# date
# 2021-06-24  0.19         NaN
# 2021-06-25  0.57         NaN
# 2021-06-26  1.03         NaN
# 2021-06-27  1.38         NaN
# 2021-06-28  1.42         NaN
# ...          ...         ...
# 2023-03-14  0.96    0.970321
# 2023-03-15  0.94    0.972533
# 2023-03-16  0.96    0.966019
# 2023-03-17  0.94    0.967000
# 2023-03-18  1.00    0.961932
#
# [633 rows x 2 columns]

# %%
#Visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Oil Rate (m³)', fontsize=18)
plt.plot(df['oil'])
plt.plot(df["prediction"])
plt.legend(['Train', 'Val', 'data_training'], loc='lower right')
plt.show()

# %%
output2 = pd.DataFrame(df)
output2.to_csv('rf.csv', index = None, encoding = "utf-8_sig", header = None)

# %%
x_train.shape
# Out:
# (407, 100, 1)

# %%
def add_remove(x,prediction):
    x = list(x)
    x[0] = list(x[0])
    x = [x[0][1:]]
    x[0].append(prediction)
    ar = np.asarray(x).astype(np.float32)
    return ar

# %%
reuslt = []
qq = a[-100:].reshape(1,100,1).astype(np.float32)
print(qq.shape)
period = 300
for i in range(period):
    temporary = model.predict(qq)
    reuslt.append(temporary)
    qq = add_remove(qq, temporary)
# Out:
# (1, 100, 1)
# C:\Users\15966\AppData\Local\Temp\ipykernel_14856\1956507870.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ar = np.asarray(x).astype(np.float32)

# %%
import random

# %%
output = []
for i in reuslt:
    a = float(i) + random.random()/50
    output.append(a)
output
# Out:
# [0.8946301917235551,
#  0.8595868057581302,
#  0.8171133485768357,
#  0.7562007383154831,
#  0.7317673982775448,
#  0.701002756916016,
#  0.6760477511290607,
#  0.657163247600179,
#  0.6418100844304896,
#  0.6440266400539548,
#  0.6346457024393081,
#  0.6129626248149158,
#  0.6123470475979078,
#  0.60840262732013,
#  0.6167600399375123,
#  0.5997537847955309,
#  0.6150997289316569,
#  0.5941665182727303,
#  0.6110923439033429,
#  0.6085887664489682,
#  0.6070661820524283,
#  0.5899609015675187,
#  0.6045424758739437,
#  0.5944734401406452,
#  0.5838653339993093,
#  0.5948164836626177,
#  0.5951779256557722,
#  0.5836522203722653,
#  0.5893466635651953,
#  0.5848584773150395,
#  0.5962082681719868,
#  0.5961264003410456,
#  0.6019460853767239,
#  0.5939487026050504,
#  0.5967487985602422,
#  0.5876638653131534,
#  0.5997093655163912,
#  0.5914748667577625,
#  0.5961931993350893,
#  0.5983277474015389,
#  0.5997289498262451,
#  0.5946237365250068,
#  0.5925690602397505,
#  0.5939660910549119,
#  0.6022491765334366,
#  0.5957665347367483,
#  0.6029699716524938,
#  0.5987030146130575,
#  0.5966395889312336,
#  0.5894969394758854,
#  0.5946745176897973,
#  0.5904928451570998,
#  0.608646769966923,
#  0.5957200285389305,
#  0.6032464191296271,
#  0.5949358496504258,
#  0.597240073522533,
#  0.6094605823538459,
#  0.6066169906793673,
#  0.596394663524501,
#  0.595725944383313,
#  0.5938006928912782,
#  0.6027725175030628,
#  0.6108786645646813,
#  0.5958963387977121,
#  0.6046335172403763,
#  0.609515045055425,
#  0.6104529573517193,
#  0.6012840911221837,
#  0.5949712526457422,
#  0.5968514714480114,
#  0.6090334310025505,
#  0.5928905841457388,
#  0.6087690374393168,
#  0.5974187854513378,
#  0.6004322517932295,
#  0.6106531404493039,
#  0.6121881766582579,
#  0.6059110166025573,
#  0.6062405294256836,
#  0.5956153988708869,
#  0.6042940579078595,
#  0.5973739404618235,
#  0.6069551559782839,
#  0.5963363721570809,
#  0.603747831329177,
#  0.6013880896742593,
#  0.5990441341487427,
#  0.6126539030670856,
#  0.6032586205742829,
#  0.6116763334981381,
#  0.6069297200065333,
#  0.599216981516425,
#  0.5966529496347076,
#  0.6136365961682029,
#  0.6128745354566927,
#  0.6115640671303821,
#  0.6071341246869946,
#  0.6000099818371147,
#  0.6080756453043612,
#  0.6099485472958297,
#  0.5990266279662,
#  0.5972529982545809,
#  0.5993640706430448,
#  0.6083590760787873,
#  0.6107951490160205,
#  0.6084273864385938,
#  0.5965012409937408,
#  0.5992464930928071,
#  0.5956808974694326,
#  0.6078974315764765,
#  0.610204515183559,
#  0.6066671571081127,
#  0.5960585508867815,
#  0.5986467942540282,
#  0.6123881798233874,
#  0.6116527984707733,
#  0.6074072699749598,
#  0.6076031546921078,
#  0.6022971000376478,
#  0.6003964893945519,
#  0.6077395200555537,
#  0.6116629822970067,
#  0.6059374769314347,
#  0.6147244984662164,
#  0.6091105504657235,
#  0.614046775509986,
#  0.6135508521225731,
#  0.6049878491549031,
#  0.6003027776717943,
#  0.6155939695338324,
#  0.6123801545519197,
#  0.6008075491682349,
#  0.6072394611446186,
#  0.5966913559456025,
#  0.605892265235268,
#  0.6081490364175569,
#  0.6059718056693812,
#  0.6030576604872062,
#  0.6039469427389489,
#  0.6017399505222971,
#  0.6120435018065102,
#  0.6073404664349846,
#  0.6022460721488068,
#  0.607154533800578,
#  0.6019485399370507,
#  0.6046191399254854,
#  0.5994448740740621,
#  0.6095026813189532,
#  0.6130121369024644,
#  0.5998861079891575,
#  0.6017209841649829,
#  0.612029500224299,
#  0.6027553779870748,
#  0.605423443196388,
#  0.5979495505626401,
#  0.5998756509017856,
#  0.5977343076689845,
#  0.606000172084071,
#  0.6045130842959314,
#  0.5969272876015808,
#  0.6087590752867229,
#  0.6027767841103797,
#  0.5962457679006331,
#  0.605496341931096,
#  0.6009553966634741,
#  0.600353868263176,
#  0.615560142185377,
#  0.6010013380288741,
#  0.6051892811557027,
#  0.6089498864928088,
#  0.5992498690861403,
#  0.6098409713939281,
#  0.606895052547962,
#  0.6115043701980003,
#  0.6022332679728232,
#  0.6071088441171502,
#  0.5967455387663334,
#  0.6125625703274062,
#  0.6079336783164583,
#  0.600770067590045,
#  0.6031743818634406,
#  0.5964671906358161,
#  0.6153575917519941,
#  0.6067116332444088,
#  0.6093011316969932,
#  0.6049018767133019,
#  0.5970645227519858,
#  0.6094634835244065,
#  0.6121510377801703,
#  0.6096872266588033,
#  0.6060577512689183,
#  0.6110238273568563,
#  0.6032379186807624,
#  0.611706011160606,
#  0.6001043978199395,
#  0.5977261520899194,
#  0.6044147244794368,
#  0.5996855229879419,
#  0.5984589149303603,
#  0.6039528574900934,
#  0.6153136454980201,
#  0.602543349449297,
#  0.6070031674380717,
#  0.6101993493372811,
#  0.5974332647813444,
#  0.6111722638795614,
#  0.615021627210113,
#  0.6034100731983949,
#  0.6121541238088799,
#  0.6104390256555813,
#  0.6017594044885879,
#  0.6061677736335831,
#  0.6142095753110935,
#  0.6025317675708097,
#  0.6056816726376245,
#  0.6058627739745319,
#  0.6017410852416296,
#  0.597810563528608,
#  0.6070883182135931,
#  0.6006211864317018,
#  0.599317791407339,
#  0.6123683178771635,
#  0.6136149165594883,
#  0.6022385244840207,
#  0.6051611174523047,
#  0.6010474807094913,
#  0.5981551835552846,
#  0.6092100659451158,
#  0.607096517321203,
#  0.5971079215282266,
#  0.6057217889405302,
#  0.5996023711804436,
#  0.6120107857711018,
#  0.6028663954686221,
#  0.6078088669393267,
#  0.609829745031438,
#  0.5968165250112722,
#  0.6155583368946684,
#  0.6058314308714463,
#  0.6076401663227607,
#  0.6100337132764924,
#  0.6111189613494897,
#  0.6114076109995961,
#  0.6074346502963163,
#  0.6066023366455923,
#  0.6004468891665837,
#  0.6144642823244658,
#  0.5987111083280018,
#  0.614671041457828,
#  0.6020670406589957,
#  0.6018746067397925,
#  0.6118267579645129,
#  0.599904250191072,
#  0.6111185467235513,
#  0.613387120676249,
#  0.6029444038906931,
#  0.5965049773430766,
#  0.6052638212875456,
#  0.6001173250735683,
#  0.6138076023581177,
#  0.6020430247163501,
#  0.5980366845879123,
#  0.6081420207122435,
#  0.6119783571586962,
#  0.6113145294560284,
#  0.6127761549263051,
#  0.6076359756379144,
#  0.6156808882980783,
#  0.6129933401873839,
#  0.6097989418893526,
#  0.6055850688241156,
#  0.5972719735846325,
#  0.6103982749175789,
#  0.6152014767388545,
#  0.5972916763427941,
#  0.6138524040805278,
#  0.6159508586573371,
#  0.6080857157164801,
#  0.6115708035390389,
#  0.6097510810422866,
#  0.6011966242520448,
#  0.6050448267925165,
#  0.6118045815748623,
#  0.6059915104196644,
#  0.6072778201245318,
#  0.6054901192093601,
#  0.6085185093190629,
#  0.5968231539994906,
#  0.6005917809672437,
#  0.615135551024476,
#  0.6006826591638004,
#  0.5973659918742477,
#  0.5993123380616062,
#  0.5989157392289306,
#  0.606336925155862,
#  0.6074508279520291,
#  0.6135180223691433,
#  0.6006630471833504,
#  0.6160785158426434]

# %%
#output2 = pd.DataFrame(output)
#output2.to_csv('result_1.csv', index = None, encoding = "utf-8_sig", header = None)
